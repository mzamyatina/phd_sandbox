# %% [markdown]
# From `ukca_chem1_strattrop_RONO2_CHEM_local.F90`
# ```fortran
# ratj_t('MeONO2    ','PHOTON    ','HO2       ','HCHO      ','NO2       ', & !   25
#      '          ', 100.000,'jmena     ') ,  &                              !   25
# ratj_t('EtONO2    ','PHOTON    ','HO2       ','MeCHO     ','NO2       ', & !   25
#      '          ', 100.000,'jmena     ') ,  &                              !   25
# ratj_t('iPrONO2   ','PHOTON    ','HO2       ','Me2CO     ','NO2       ', & !   25
#      '          ', 100.000,'jmena     ') ,  &                              !   25
# ratj_t('nPrONO2   ','PHOTON    ','HO2       ','EtCHO     ','NO2       ', & !   26
#      '          ', 100.000,'jmena     ') ,  &                              !   26 ```
# From `FJX_spec.dat`
# ```fortran
# w-eff (nm)      187.      191.      193.      196.      202.      208.
#                 211.      214.      261.      267.      277.      295.
#                 303.      310.      316.      333.      380.      574.
# SOL#/cm2/s 1.391E+12 1.627E+12 1.664E+12 9.278E+11 7.842E+12 4.680E+12
#            9.918E+12 1.219E+13 6.364E+14 4.049E+14 3.150E+14 5.889E+14
#            7.678E+14 5.045E+14 8.902E+14 3.853E+15 1.547E+16 2.131E+17
# jmena  240 0.000E+00 0.000E+00 0.000E+00 0.000E+00 0.000E+00 0.000E+00
#            0.000E+00 0.000E+00 2.337E-20 1.004E-20 6.638E-21 4.679E-21
#            2.022E-21 9.381E-22 3.730E-22 3.755E-23 0.000E+00 0.000E+00
# jmena  298 0.000E+00 0.000E+00 0.000E+00 0.000E+00 0.000E+00 0.000E+00
#            0.000E+00 0.000E+00 2.788E-20 1.233E-20 8.359E-21 6.029E-21
#            2.735E-21 1.346E-21 5.734E-22 6.957E-23 0.000E+00 0.000E+00```

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from pathlib import Path
plt.rcParams['mathtext.default'] = 'regular'

# %%
path_to_results = Path('../results/rates')

# %% [markdown]
# #### Absorption cross sections for 298K

# %%
# IUPAC C1-C3 RONO2 absorption cross sections
meono2_iupac_wvlngths = np.arange(240, 345,5)
meono2_iupac_sigma_298K = np.array([5.88, 4.19, 3.59, 3.30, 3.06, 2.77, 2.39, 2.00, 1.58, 1.19, 0.85, 
                                    0.568, 0.360, 0.214, 0.134, 0.0633, 0.0316, 0.0144, 0.00661, 0.00274, 0.00122]) # times 1e20
etono2_iupac_wvlngths = np.arange(185,345,5)
etono2_iupac_sigma_298K = np.array([1710, 1710, 1490, 1140, 738, 400, 195, 91, 45, 24, 11.9, 7.7, 5.4, 4.5, 4.1, 3.9,
                                    3.6, 3.1, 2.7, 2.2, 1.7, 1.2, 0.85, 0.55, 0.33, 0.19, 0.10, 0.051, 0.026, 0.012, 0.0049, 0.0025]) # times 1e20
nprono2_iupac_wvlngths = np.arange(185,345,5)
nprono2_iupac_sigma_298K = np.array([1810, 1800, 1600, 1260, 855, 489, 244, 105, 50, 27, 15, 8.9, 6.0, 4.8, 4.4, 4.0,
                                     3.6, 3.2, 2.8, 2.3, 1.8, 1.3, 0.95, 0.57, 0.34, 0.19, 0.10, 0.053, 0.031, 0.022, 0.018, 0.016]) # times 1e20
iprono2_iupac_wvlngths = np.array([185, 188, 190, 195, 200, 205, 210, 215, 220, 225, 230, 235, 240, 245, 250, 255,
                                   275, 280, 285, 290, 295, 300, 305, 310, 315, 320, 325, 330, 335, 340, 345, 350])
iprono2_iupac_sigma_298K = np.array([1790, 1810, 1790, 1610, 1260, 867, 498, 247, 125, 62, 34, 18, 11, 7.0, 5.4, 4.9,
                                     3.4, 2.8, 2.2, 1.6, 1.2, 0.78, 0.50, 0.29, 0.17, 0.085, 0.044, 0.022, 0.011, 0.0053, 0.0018, 0.00080]) # times 1e20
# JPL MeONO2 absorption cross section (others are absent)
meono2_jpl_wvlngths = np.array([190, 195, 200, 205, 210, 215, 220, 225, 230, 235, 236, 238, 240, 242, 244, 246, 248, 250, 252, 254, 256, 258,
                                260, 262, 264, 266, 268, 270, 272, 274, 276, 278, 280, 282, 284, 286, 288, 290, 292, 294, 296, 298, 300, 302,
                                304, 306, 308, 310, 312, 314, 316, 318, 320, 322, 324, 326, 328, 330, 332, 334, 336, 338, 340, 342, 344])
meono2_jpl_sigma_298K = np.array([1800, 1500, 1180, 700, 360, 145, 70, 33, 18, 10, 8.27, 6.77, 5.66, 4.88, 4.34, 3.97, 3.72, 3.56, 3.44, 3.34, 3.25, 3.16,
                                  3.07, 2.96, 2.84, 2.72, 2.57, 2.42, 2.27, 2.10, 1.94, 1.77, 1.61, 1.45, 1.29, 1.14, 1.00, 0.871, 0.754, 0.642, 0.519, 
                                  0.435, 0.364, 0.298,
                                  0.241, 0.194, 0.154, 0.121, 0.0940, 0.0723, 0.0548, 0.0412, 0.0304, 0.0228, 0.0164, 0.01187, 0.00868, 0.00618, 0.00447, 
                                  0.00311, 0.00216, 0.00161, 0.00116, 0.000812, 0.0004687])
# UKCA MeONO2 absorption cross section
ukca_wvlngths = np.array([187, 191, 193, 196, 202, 208, 
                          211, 214, 261, 267, 277, 295,
                          303, 310, 316, 333, 380, 574])
ukca_sigma_298K = np.array([np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 
                            np.nan, np.nan, 2.788E-20, 1.233E-20, 8.359E-21, 6.029E-21,
                            2.735E-21, 1.346E-21, 5.734E-22, 6.957E-23, np.nan, np.nan])*1e20 # same for 240K
# Interpolate data onto UKCA bins
meono2_jpl_sigma_298K_interp = np.interp(ukca_wvlngths[8:-2], meono2_jpl_wvlngths[22:60], meono2_jpl_sigma_298K[22:60])
meono2_iupac_sigma_298K_interp = np.interp(ukca_wvlngths[8:-2], meono2_iupac_wvlngths[4:-1], meono2_iupac_sigma_298K[4:-1])

etono2_iupac_sigma_298K_interp = np.interp(ukca_wvlngths[8:-2], etono2_iupac_wvlngths[15:-1], etono2_iupac_sigma_298K[15:-1])
nprono2_iupac_sigma_298K_interp = np.interp(ukca_wvlngths[8:-2], nprono2_iupac_wvlngths[15:-1], nprono2_iupac_sigma_298K[15:-1])
iprono2_iupac_sigma_298K_interp = np.interp(ukca_wvlngths[8:-2], iprono2_iupac_wvlngths[15:-3], iprono2_iupac_sigma_298K[15:-3])

# %%
# Solar actinic flux at the surface
solar_flux = [1.391E+12, 1.627E+12, 1.664E+12, 9.278E+11, 7.842E+12, 4.680E+12,
              9.918E+12, 1.219E+13, 6.364E+14, 4.049E+14, 3.150E+14, 5.889E+14,
              7.678E+14, 5.045E+14, 8.902E+14, 3.853E+15, 1.547E+16, 2.131E+17]

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(14,5))
ax[0].plot(meono2_jpl_wvlngths, meono2_jpl_sigma_298K, label='JPL $MeONO_2$', color='C0', alpha=0.6)
ax[0].plot(meono2_iupac_wvlngths, meono2_iupac_sigma_298K, label='IUPAC $MeONO_2$', color='C0')
ax[0].plot(etono2_iupac_wvlngths, etono2_iupac_sigma_298K, label='IUPAC $EtONO_2$', color='C1')
ax[0].plot(nprono2_iupac_wvlngths, nprono2_iupac_sigma_298K, label='IUPAC $nPrONO_2$', color='C2')
ax[0].plot(iprono2_iupac_wvlngths, iprono2_iupac_sigma_298K, label='IUPAC $iPrONO_2$', color='C3')
ax[0].plot(ukca_wvlngths, ukca_sigma_298K, label='UKCA $C_1$-$C_3$ $RONO_2$', marker='o', color='C4')
rect0 = patches.Rectangle((245,-60), 110, 130, linewidth=1, edgecolor='k', facecolor='none')
ax[0].add_patch(rect0)
ax0 = ax[0].twinx()
ax0.plot(ukca_wvlngths, solar_flux, label='Solar actinic flux', linestyle='--', color='k')

ax[0].legend(frameon=False, loc='upper left', bbox_to_anchor=(0.07,1))
ax0.legend(frameon=False, loc='upper left', bbox_to_anchor=(0.07,0.665)) # 0.07,0.58

ax[1].plot(meono2_jpl_wvlngths, meono2_jpl_sigma_298K, label='JPL $MeONO_2$', color='C0', alpha=0.6)
ax[1].plot(meono2_iupac_wvlngths, meono2_iupac_sigma_298K, label='IUPAC $MeONO_2$', color='C0')
ax[1].plot(etono2_iupac_wvlngths, etono2_iupac_sigma_298K, label='IUPAC $EtONO_2$', color='C1')
ax[1].plot(nprono2_iupac_wvlngths, nprono2_iupac_sigma_298K, label='IUPAC $nPrONO_2$', color='C2')
ax[1].plot(iprono2_iupac_wvlngths, iprono2_iupac_sigma_298K, label='IUPAC $iPrONO_2$', color='C3')
ax[1].plot(ukca_wvlngths, ukca_sigma_298K, label='UKCA $C_1$-$C_3$ $RONO_2$', marker='o', color='C4')
ax[1].set_xlim(250,350)
ax[1].set_ylim(-0.35,7)
ax1 = ax[1].twinx()
ax1.plot(ukca_wvlngths[8:-2], solar_flux[8:-2], label='Solar actinic flux', linestyle='--', color='k')

ax[2].plot(ukca_wvlngths[12:-2], (ukca_sigma_298K[8:-2]-meono2_jpl_sigma_298K_interp)[4:]*100, marker='o', color='C0', alpha=0.6)
ax[2].plot(ukca_wvlngths[12:-2], (ukca_sigma_298K[8:-2]-meono2_iupac_sigma_298K_interp)[4:]*100, marker='o', color='C0')
ax[2].plot(ukca_wvlngths[12:-2], (ukca_sigma_298K[8:-2]-etono2_iupac_sigma_298K_interp)[4:]*100, marker='o', color='C1')
ax[2].plot(ukca_wvlngths[12:-2], (ukca_sigma_298K[8:-2]-nprono2_iupac_sigma_298K_interp)[4:]*100, marker='o', color='C2')
ax[2].plot(ukca_wvlngths[12:-2], (ukca_sigma_298K[8:-2]-iprono2_iupac_sigma_298K_interp)[4:]*100, marker='o', color='C3')
ax[2].set_ylabel('$\Delta$, %')
ax[2].set_xlim(300,340)

ax3 = inset_axes(ax[2], 1.5, 1.5, loc='lower right', borderpad=2)
ax3.plot(ukca_wvlngths[8:-2], (ukca_sigma_298K[8:-2]-etono2_iupac_sigma_298K_interp)*100, marker='o', color='C1');
ax3.plot(ukca_wvlngths[8:-2], (ukca_sigma_298K[8:-2]-nprono2_iupac_sigma_298K_interp)*100, marker='o', color='C2');
ax3.plot(ukca_wvlngths[8:-2], (ukca_sigma_298K[8:-2]-iprono2_iupac_sigma_298K_interp)*100, marker='o', color='C3');
ax3.set_xlim(250,350)
rect3 = patches.Rectangle((298,-50), 40, 60, linewidth=1, edgecolor='k', facecolor='none')
ax3.add_patch(rect3)

fig.suptitle('$C_1$-$C_3$ $RONO_2$ absorption cross sections at 298 K')
for iax in ax.flatten(): iax.set_xlabel(r'$\lambda$, nm')
ax[0].set_ylabel(r'$10^{20}\sigma$, $cm^{2}$ $molecule^{-1}$')
ax[1].set_ylabel(r'$10^{20}\sigma$, $cm^{2}$ $molecule^{-1}$')
ax0.set_ylabel('Solar actinic flux, photon $cm^{-2}$ $s^{-1}$ $nm^{-1}$')
ax1.set_ylabel('Solar actinic flux, photon $cm^{-2}$ $s^{-1}$ $nm^{-1}$')
fig.subplots_adjust(wspace=0.45)
fig.savefig(path_to_results / 'rono2_hv.png', bbox_inches='tight', dpi=300)
# strangely, .png file has 'solar actinic flux' not overlapping with other legend labels

# %%
break

# %% [markdown]
# #### T-dependent absorption cross sections

# %%
# Unfinished
iupac_wvlngths = np.arange(240, 335, 5)
iupac_sigma_298K = np.array([5.88, 4.19, 3.59, 3.30, 3.06, 2.77, 2.39, 2.00, 1.58, 
                             1.19, 0.85, 0.568, 0.360, 0.214, 0.134, 0.0633, 0.0316, 0.0144, 0.00661])
iupac_B = np.array([3.48, 3.29, 2.96, 2.82, 2.83, 2.92, 3.08, 3.28, 3.51, 
                    3.78, 4.04, 4.47, 4.94, 5.56, 6.33, 7.34, 8.74, 9.97, 13.6])*1e3
iupac_temps = np.arange(240, 331, 1)

# %%
ln_sigma_240_330K = np.zeros((len(wvlngths),len(temps)))
for i, (w, b, s) in enumerate(zip(wvlngths, B, sigma_298K)):
    for j, t in enumerate(temps):
        ln_sigma_240_330K[i,j] = np.log(s) + b*(t-298)

# %%
plt.plot(wvlngths, ln_sigma_240_330K[:,0]/1e20)
plt.plot(wvlngths, ln_sigma_240_330K[:,19]/1e20)
