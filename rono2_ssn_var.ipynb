# %%
import calendar
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
plt.rcParams['mathtext.default'] = 'regular'

# %%
path_to_results = Path.cwd().parent / 'results' / 'misc'

# %%
# 'Yearly'
# Flocke et al (1998) Schauinsland, Germany
flocke1998_meono2_mean = 26.2
flocke1998_etono2_mean = 11.8
flocke1998_nprono2_mean = 3.9
flocke1998_iprono2_mean = 13.9
flocke1998_nbuono2_mean = 2.4
flocke1998_sibuono2_mean = 15.8 # sBuONO2+iBuONO2
flocke1998_npebono2_mean = 6.5
flocke1998_npecono2_mean = 4.5
# Simpson et al (2006) Tai O, China
simpson2006_meono2_mean = 7.5
simpson2006_etono2_mean = 7.3
simpson2006_nprono2_mean = 3.2
simpson2006_iprono2_mean = 21.0
simpson2006_sbuono2_mean = 26.3
simpson2006_npebono2_mean = 6.8
simpson2006_npecono2_mean = 6.1

simpson2006_meono2_std = 4.2
simpson2006_etono2_std = 3.6
simpson2006_nprono2_std = 2.1
simpson2006_iprono2_std = 10.7
simpson2006_sbuono2_std = 15.4
simpson2006_npebono2_std = 4.3
simpson2006_npecono2_std = 3.6
# Monthly
# Swanson et al (2003) Summit, Greenland
swanson2003_meono2_mean = [4.54, 4.93, 4.38, 4.27, 4.28, 3.09, 3.97, 3.76, 2.97, 3.09, 3.96, 4.25]
swanson2003_etono2_mean = [4.70, 5.64, 4.99, 4.96, 5.37, 4.27, 3.59, 2.88, 2.86, 2.91, 3.73, 4.23]
swanson2003_nprono2_mean = [1.79, 1.91, 1.82, 1.84, 1.60, 0.96, 0.64, np.nan, 0.50, 0.53, 0.92, 1.35]
swanson2003_iprono2_mean = [7.96, 9.13, 9.49, 9.02, 8.36, 5.29, 2.38, 1.26, 2.16, 3.60, 5.67, 7.02]
swanson2003_sbuono2_mean = [9.38, 11.23, 12.58, 11.44, 9.67, 5.35, 1.80, 1.52, 1.74, 3.44, 5.50, 7.94]

swanson2003_meono2_1sigma = [0.39, 0.43, 0.43, 0.50, 1.48, 0.36, 1.01, 0.84, 0.48, 0.65, 0.39, 0.43]
swanson2003_etono2_1sigma = [0.63, 0.85, 0.85, 0.65, 1.96, 0.62, 0.87, 0.66, 0.51, 0.56, 0.34, 0.54]
swanson2003_nprono2_1sigma = [0.71, 0.40, 0.49, 0.57, 0.61, 0.26, 0.19, np.nan, 0.25, 0.19, 0.23, 0.29]
swanson2003_iprono2_1sigma = [0.49, 0.89, 0.82, 0.93, 1.54, 1.28, 0.79, 0.56, 0.34, 1.25, 0.92, 0.57]
swanson2003_sbuono2_1sigma = [1.20, 1.72, 1.13, 1.62, 1.73, 1.56, 1.16, 0.98, 0.75, 2.02, 1.15, 1.15]
# Russo et al (2010) Thompson Farm, NH
russo2010_meono2_mean = [3.0, 3.4, 3.4, 3.2, 3.2, 3.1, 3.0, 3.0, 3.0, 3.0, 3.2, 3.1]
russo2010_etono2_mean = [2.7, 2.8, 3.2, 2.9, 2.7, 2.9, 2.6, 2.2, 2.3, 2.5, 2.8, 2.6]
russo2010_nprono2_mean = [0.8, 0.9, 0.9, 0.8, 0.7, 0.7, 0.7, 0.6, 0.6, 0.7, 0.7, 0.8]
russo2010_iprono2_mean = [6.2, 6.8, 7.7, 6.2, 4.9, 5.0, 5.4, 4.6, 4.9, 5.1, 5.9, 6.3]
russo2010_sbuono2_mean = [7.2, 7.5, 7.7, 5.2, 3.2, 3.2, 3.1, 2.9, 3.6, 4.5, 6.1, 7.0]
russo2010_npebono2_mean = [2.8, 3.0, 3.0, 1.9, 1.5, 2.1, 1.6, 1.7, 1.9, 1.8, 2.5, 2.6]
russo2010_npecono2_mean = [2.4, 2.8, 2.7, 1.7, 1.4, 1.7, 1.5, 1.5, 1.6, 1.7, 2.1, 2.2]

russo2010_meono2_std = [0.5, 0.4, 0.5, 0.4, 0.4, 0.9, 0.9, 0.9, 0.9, 0.6, 0.5, 0.4]
russo2010_etono2_std = [0.6, 0.6, 0.9, 0.7, 0.8, 1.5, 1.2, 1.0, 1.1, 0.8, 1.2, 0.6]
russo2010_nprono2_std = [0.3, 0.3, 0.3, 0.3, 0.5, 0.5, 0.4, 0.3, 0.4, 0.4, 0.3, 0.4]
russo2010_iprono2_std = [2.0, 1.8, 2.8, 2.1, 2.3, 3.7, 3.4, 2.8, 3.2, 2.8, 2.0, 2.8]
russo2010_sbuono2_std = [2.7, 2.6, 3.0, 2.0, 1.8, 2.7, 2.2, 2.1, 2.8, 3.1, 2.6, 4.1]
russo2010_npebono2_std = [1.3, 1.3, 1.7, 1.0, 1.1, 1.8, 1.1, 1.2, 1.4, 1.2, 1.2, 1.5]
russo2010_npecono2_std = [1.1, 1.2, 1.6, 0.9, 1.0, 1.5, 1.0, 1.0, 1.2, 1.0, 0.9, 1.2]

# %%
mns = np.arange(1,13)
xticklbls = ['']+[calendar.month_abbr[i] for i in mns]+['Year']
errorbar_dict = dict(fmt='-o', capsize=3)

# %%
fig, ax = plt.subplots(figsize=(11,12), ncols=2, nrows=4, sharex=True, sharey=True)

ax[0,0].errorbar([np.nan]*12+[13], [np.nan]*12+[flocke1998_meono2_mean], label='Schauinsland, Germany', fmt='-o')
ax[0,0].errorbar(mns, swanson2003_meono2_mean, yerr=swanson2003_meono2_1sigma, label='Summit, Greenland', **errorbar_dict)
ax[0,0].errorbar([np.nan]*12+[13], [np.nan]*12+[simpson2006_meono2_mean], yerr=simpson2006_meono2_std, label='Tai O, China', **errorbar_dict)
ax[0,0].errorbar(mns, russo2010_meono2_mean, yerr=russo2010_meono2_std, label='Thompson Farm, USA', **errorbar_dict)

ax[0,1].errorbar([np.nan]*12+[13], [np.nan]*12+[flocke1998_etono2_mean], fmt='-o')
ax[0,1].errorbar(mns, swanson2003_etono2_mean, yerr=swanson2003_etono2_1sigma, **errorbar_dict)
ax[0,1].errorbar([np.nan]*12+[13], [np.nan]*12+[simpson2006_etono2_mean], yerr=simpson2006_meono2_std, **errorbar_dict)
ax[0,1].errorbar(mns, russo2010_etono2_mean, yerr=russo2010_etono2_std, **errorbar_dict)

ax[1,0].errorbar([np.nan]*12+[13], [np.nan]*12+[flocke1998_nprono2_mean], fmt='-o')
ax[1,0].errorbar(mns, swanson2003_nprono2_mean, yerr=swanson2003_nprono2_1sigma, **errorbar_dict)
ax[1,0].errorbar([np.nan]*12+[13], [np.nan]*12+[simpson2006_nprono2_mean], yerr=simpson2006_meono2_std, **errorbar_dict)
ax[1,0].errorbar(mns, russo2010_nprono2_mean, yerr=russo2010_nprono2_std, **errorbar_dict)

ax[1,1].errorbar([np.nan]*12+[13], [np.nan]*12+[flocke1998_iprono2_mean], fmt='-o')
ax[1,1].errorbar(mns, swanson2003_iprono2_mean, yerr=swanson2003_iprono2_1sigma, **errorbar_dict)
ax[1,1].errorbar([np.nan]*12+[13], [np.nan]*12+[simpson2006_iprono2_mean], yerr=simpson2006_meono2_std, **errorbar_dict)
ax[1,1].errorbar(mns, russo2010_iprono2_mean, yerr=russo2010_iprono2_std, **errorbar_dict)

ax[2,0].errorbar([np.nan]*12+[13], [np.nan]*12+[flocke1998_nbuono2_mean], fmt='-o')

ax[2,1].errorbar([np.nan]*12+[13], [np.nan]*12+[flocke1998_sibuono2_mean], fmt='-o')
ax[2,1].errorbar(mns, swanson2003_sbuono2_mean, yerr=swanson2003_sbuono2_1sigma, **errorbar_dict)
ax[2,1].errorbar([np.nan]*12+[13], [np.nan]*12+[simpson2006_sbuono2_mean], yerr=simpson2006_meono2_std, **errorbar_dict)
ax[2,1].errorbar(mns, russo2010_sbuono2_mean, yerr=russo2010_sbuono2_std, **errorbar_dict)

ax[3,0].errorbar([np.nan]*12+[13], [np.nan]*12+[flocke1998_npebono2_mean], fmt='-o')
ax[3,0].errorbar(mns, [np.nan]*12, yerr=[np.nan]*12, **errorbar_dict)
ax[3,0].errorbar([np.nan]*12+[13], [np.nan]*12+[simpson2006_npebono2_mean], yerr=simpson2006_meono2_std, **errorbar_dict)
ax[3,0].errorbar(mns, russo2010_npebono2_mean, yerr=russo2010_npebono2_std, **errorbar_dict)

ax[3,1].errorbar([np.nan]*12+[13], [np.nan]*12+[flocke1998_npecono2_mean], fmt='-o')
ax[3,1].errorbar(mns, [np.nan]*12, yerr=[np.nan]*12, **errorbar_dict)
ax[3,1].errorbar([np.nan]*12+[13], [np.nan]*12+[simpson2006_npecono2_mean], yerr=simpson2006_meono2_std, **errorbar_dict)
ax[3,1].errorbar(mns, russo2010_npecono2_mean, yerr=russo2010_npecono2_std, **errorbar_dict)

ax[0,0].set_title('$MeONO_2$')
ax[0,1].set_title('$EtONO_2$')
ax[1,0].set_title('$nPrONO_2$')
ax[1,1].set_title('$iPrONO_2$')
ax[2,0].set_title('$nBuONO_2$')
ax[2,1].set_title('$sBuONO_2$')
ax[3,0].set_title('$nPeBONO_2$')
ax[3,1].set_title('$nPeCONO_2$')
ax[1,0].set_xticks(np.arange(len(xticklbls)))
ax[1,0].set_xticklabels(xticklbls)
ax[0,0].set_ylabel('ppt')
ax[1,0].set_ylabel('ppt')
ax[0,0].legend(frameon=False)
fig.subplots_adjust(wspace=0.1);
fig.savefig(path_to_results / 'rono2_seasons_c1c5.png', bbox_inches='tight', dpi=300)
